# %%
import os

# %%
os.getcwd()
# Out:
# 'C:\\Users\\kamal'

# %%
import pandas as pd

# %%
pd.read_excel(r'tatttt.xlsx')
# Out:
#    Application ID Lender Reference Number First Name  Last Name  \
# 0       1-1ZCFP6K                 5170012     Yianna  Matsoukas
# 1       1-1TXN23W             101-603-070      Refai     Hamzah
# 2       1-1G228MF                 6013785       Amid    Sabbagh
# 3       1-1FZOOI1                PA816350       Naji      Taouk
# 4       1-1G5KUME                PA817040     Dorian      Ledru
# 5       1-1G71WEL                  123883       Adam   Beaulieu
# 6       1-1G5N119                PA817110   Romanous    Jabbour
# 7       1-1G5IOQT                PA817079     Dorian      Ledru
# 8       1-1GKFC2U                 6886947  Bridgette       Azzi
# 9       1-1GEW2CL                  125129    Mansour      Taouk
# 10      1-1GZM6FV                  125775     Melina    Raineri
# 11      1-1H8DQH4                10555492       Ziad     Merheb
# 12      1-1HD05A8                  126986      Danio    Azzario
#
#     Proposed Loan Amount
# 0              840000.00
# ...

# %%
pd.read_csv('https://raw.githubusercontent.com/dsrscientist/dataset5/main/termdeposit_test.csv')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Input In [1], in <cell line: 1>()
# ----> 1 pd.read_csv('https://raw.githubusercontent.com/dsrscientist/dataset5/main/termdeposit_test.csv')
#
# NameError: name 'pd' is not defined

# %%
import pandas as pd

# %%
pd.read_csv("https://raw.githubusercontent.com/dsrscientist/dataset5/main/termdeposit_train.csv")
# Out:
#           ID  age         job   marital  education default  balance housing  \
# 0      26110   56      admin.   married    unknown      no     1933      no
# 1      40576   31     unknown   married  secondary      no        3      no
# 2      15320   27    services   married  secondary      no      891     yes
# 3      43962   57  management  divorced   tertiary      no     3287      no
# 4      29842   31  technician   married  secondary      no      119     yes
# ...      ...  ...         ...       ...        ...     ...      ...     ...
# 31642  36483   29  management    single   tertiary      no        0     yes
# 31643  40178   53  management  divorced   tertiary      no      380      no
# 31644  19710   32  management    single   tertiary      no      312      no
# 31645  38556   57  technician   married  secondary      no      225     yes
# 31646  14156   55  management  divorced  secondary      no      204     yes
#
# ...
